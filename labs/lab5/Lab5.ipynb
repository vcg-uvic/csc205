# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
# Let's open the two images and take a look
fig, ax = plt.subplots(1, 2)
impear = cv2.imread('pear.jpg', 0)
imbridge = cv2.imread('bridge.jpg', 0)
ax[0].imshow(impear, cmap='gray')
ax[1].imshow(imbridge, cmap='gray')

# %%
# histogram of the pear
h, _, _ = plt.hist(impear.ravel(), 256, [0, 255])

# %%
# cumulative histogram of the pear
H, _, _ = plt.hist(impear.ravel(), 256, [0, 255], cumulative=1)

# %%
def match_histograms(pixels, Href, nref):
    height, width = pixels.shape
    n = height * width
    r = n / nref
    h, _ = np.histogram(pixels, bins=256, range=(0, 255))
    F = [0] * 256
    i, j, c = 0, 0, 0
    
    # TODO write your code here
    
    return F

# %%
# use the match_histograms algorithm to match the histogram of the bridge 
# to the histogram of the pear
impear_height, impear_width = impear.shape
F = match_histograms(imbridge, H, impear_height * impear_width)
mapping = np.vectorize(lambda i: F[i])
im = mapping(imbridge)

# %%
plt.imshow(im, cmap='gray')

# %%
# as you can see, this histogram of the bridge is roughly the same 
# as the pear now
H, _, _ = plt.hist(im.ravel(), 256, [0, 255], cumulative=1)
