# %%
# Library imports
import numpy as np
import cv2

# Load display library for jupyter notebook
from matplotlib import pyplot as plt

# %%
# Load example image
img = cv2.imread("../images/waikato.jpg")

# Display iamge
plt.figure()
plt.imshow(img) # <-- inverted!! (opencv reads BGR!)

# %%
# Convert image to RGB
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.imshow(img) # Proper looking (at least for now)

# %%
# Convert image to Grayscale
grey_img = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)

plt.imshow(grey_img, cmap="gray")

# %%
# What an image looks like
img
# Out:
# array([[[207, 223, 238],
#         [207, 223, 238],
#         [207, 223, 238],
#         ...,
#         [249, 249, 251],
#         [248, 248, 250],
#         [248, 248, 250]],
#
#        [[207, 223, 238],
#         [208, 224, 239],
#         [208, 224, 239],
#         ...,
#         [249, 249, 251],
#         [250, 250, 252],
#         [251, 251, 253]],
#
#        [[206, 222, 237],
#         [207, 223, 238],
#         [208, 224, 239],
#         ...,
#         [249, 249, 251],
#         [251, 251, 253],
#         [253, 253, 255]],
#
#        ...,
#
#        [[143, 133, 124],
#         [140, 130, 121],
#         [139, 130, 121],
#         ...,
#         [134, 125,  70],
#         [134, 125,  68],
#         [134, 125,  68]],
#
#        [[147, 134, 128],
#         [144, 131, 125],
#         [136, 125, 119],
#         ...,
#         [133, 123,  70],
#         [133, 124,  69],
#         [131, 122,  67]],
#
#        [[143, 130, 124],
#         [143, 130, 124],
#         [136, 125, 119],
#         ...,
#         [125, 115,  62],
#         [127, 118,  63],
#         [124, 115,  60]]], dtype=uint8)
