# %%
# Library imports
import numpy as np
import cv2

# Load display library for jupyter notebook
from matplotlib import pyplot as plt

# %%
# Load example image
img = cv2.imread("../images/waikato.jpg")

# Display image
plt.figure()
plt.imshow(img)

# %%
# Convert image to RGB
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.imshow(img)

# %%
# Convert image to Grayscale
grey_img = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)

plt.imshow(grey_img, cmap="gray")

# %%
# What an image looks like
img.shape
# Out:
# (1944, 2592, 3)

# %%
img
# Out:
# array([[[238, 223, 207],
#         [238, 223, 207],
#         [238, 223, 207],
#         ...,
#         [251, 249, 249],
#         [250, 248, 248],
#         [250, 248, 248]],
#
#        [[238, 223, 207],
#         [239, 224, 208],
#         [239, 224, 208],
#         ...,
#         [251, 249, 249],
#         [252, 250, 250],
#         [253, 251, 251]],
#
#        [[237, 222, 206],
#         [238, 223, 207],
#         [239, 224, 208],
#         ...,
#         [251, 249, 249],
#         [253, 251, 251],
#         [255, 253, 253]],
#
#        ...,
#
#        [[124, 133, 143],
#         [121, 130, 140],
#         [121, 130, 139],
#         ...,
#         [ 70, 125, 134],
#         [ 68, 125, 134],
#         [ 68, 125, 134]],
#
#        [[128, 134, 147],
#         [125, 131, 144],
#         [119, 125, 136],
#         ...,
#         [ 70, 123, 133],
#         [ 69, 124, 133],
#         [ 67, 122, 131]],
#
#        [[124, 130, 143],
#         [124, 130, 143],
#         [119, 125, 136],
#         ...,
#         [ 62, 115, 125],
#         [ 63, 118, 127],
#         [ 60, 115, 124]]], dtype=uint8)

# %%
grey_img
# Out:
# array([[226, 226, 226, ..., 250, 249, 249],
#        [226, 227, 227, ..., 250, 251, 252],
#        [225, 226, 227, ..., 250, 252, 254],
#        ...,
#        [131, 128, 128, ..., 110, 109, 109],
#        [134, 131, 124, ..., 108, 109, 107],
#        [130, 130, 124, ..., 100, 103, 100]], dtype=uint8)

# %%
grey_img.shape
# Out:
# (1944, 2592)
